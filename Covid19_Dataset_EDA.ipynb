# %% [markdown]
# <a href="https://colab.research.google.com/github/Rahul-Chouhan-407/Practice_and_Assignments/blob/main/Covid19_Dataset_EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("/content/covid_data.csv", parse_dates = ["date"])

# %%
df.sample(10)
# Out:
#             location       date  new_cases  new_deaths   population  \
# 398          Algeria 2020-06-04          0           0   43851043.0
# 20137    Switzerland 2020-01-10          0           0    8654618.0
# 22821       Zimbabwe 2020-05-08          0           0   14862927.0
# 9935       Indonesia 2020-05-20        486          30  273523621.0
# 17860     San Marino 2020-02-01          0           0      33938.0
# 16706    Philippines 2020-05-12        292           7  109581085.0
# 9174        Honduras 2020-03-23          1           0    9904608.0
# 9205        Honduras 2020-04-23          9           1    9904608.0
# 15069  New Caledonia 2020-05-28          0           0     285491.0
# 4662         Comoros 2020-05-16          0           0     869595.0
#
#        aged_65_older_percent  gdp_per_capita  hospital_beds_per_thousand
# 398                    6.211       13913.839                        1.90
# 20137                 18.436       57410.166                        4.53
# ...

# %%
df.columns
# Out:
# Index(['location', 'date', 'new_cases', 'new_deaths', 'population',
#        'aged_65_older_percent', 'gdp_per_capita',
#        'hospital_beds_per_thousand'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23018 entries, 0 to 23017
# Data columns (total 8 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   location                    23018 non-null  object
#  1   date                        23018 non-null  datetime64[ns]
#  2   new_cases                   23018 non-null  int64
#  3   new_deaths                  23018 non-null  int64
#  4   population                  23018 non-null  int64
#  5   aged_65_older_percent       20643 non-null  float64
#  6   gdp_per_capita              20711 non-null  float64
#  7   hospital_beds_per_thousand  19144 non-null  float64
# dtypes: datetime64[ns](1), float64(3), int64(3), object(1)
# memory usage: 1.6+ MB

# %%
df['population'].isnull().sum()
# Out:
# 64

# %%
nan_population = df[df['population'].isnull()]
nan_population
# Out:
#             location       date  new_cases  new_deaths  population  \
# 23018  International 2019-12-31          0           0         NaN
# 23019  International 2020-01-01          0           0         NaN
# 23020  International 2020-01-02          0           0         NaN
# 23021  International 2020-01-03          0           0         NaN
# 23022  International 2020-01-04          0           0         NaN
# ...              ...        ...        ...         ...         ...
# 23077  International 2020-02-28          0           0         NaN
# 23078  International 2020-02-29          0           2         NaN
# 23079  International 2020-03-01          0           0         NaN
# 23080  International 2020-03-02          0           0         NaN
# 23081  International 2020-03-10         -9           1         NaN
#
#        aged_65_older_percent  gdp_per_capita  hospital_beds_per_thousand
# 23018                    NaN             NaN                         NaN
# ...

# %%
df.dropna(subset=['population'], inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23018 entries, 0 to 23017
# Data columns (total 8 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   location                    23018 non-null  object
#  1   date                        23018 non-null  datetime64[ns]
#  2   new_cases                   23018 non-null  int64
#  3   new_deaths                  23018 non-null  int64
#  4   population                  23018 non-null  int64
#  5   aged_65_older_percent       20643 non-null  float64
#  6   gdp_per_capita              20711 non-null  float64
#  7   hospital_beds_per_thousand  19144 non-null  float64
# dtypes: datetime64[ns](1), float64(3), int64(3), object(1)
# memory usage: 1.6+ MB

# %%
df['population'] = df['population'].astype('int')

# %%
df['gdp_per_capita'].isnull().sum()
# Out:
# 2307

# %%
nan_gdp = df[df['gdp_per_capita'].isnull()]
nan_gdp
# Out:
#              location       date  new_cases  new_deaths  population  \
# 405           Andorra 2020-03-03          1           0       77265
# 406           Andorra 2020-03-14          1           0       77265
# 407           Andorra 2020-03-16          3           0       77265
# 408           Andorra 2020-03-17          9           0       77265
# 409           Andorra 2020-03-18          0           0       77265
# ...               ...        ...        ...         ...         ...
# 22622  Western Sahara 2020-06-06          0           0      597330
# 22623  Western Sahara 2020-06-07          0           0      597330
# 22624  Western Sahara 2020-06-08          0           0      597330
# 22625  Western Sahara 2020-06-09          0           0      597330
# 22626  Western Sahara 2020-06-10          0           0      597330
#
#        aged_65_older_percent  gdp_per_capita  hospital_beds_per_thousand
# 405                      NaN             NaN                         NaN
# ...

# %%
df.dropna(subset=['gdp_per_capita'], inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 20711 entries, 0 to 23017
# Data columns (total 8 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   location                    20711 non-null  object
#  1   date                        20711 non-null  datetime64[ns]
#  2   new_cases                   20711 non-null  int64
#  3   new_deaths                  20711 non-null  int64
#  4   population                  20711 non-null  int64
#  5   aged_65_older_percent       20062 non-null  float64
#  6   gdp_per_capita              20711 non-null  float64
#  7   hospital_beds_per_thousand  18647 non-null  float64
# dtypes: datetime64[ns](1), float64(3), int64(3), object(1)
# memory usage: 1.4+ MB

# %%
nan_aged65 = df[df['aged_65_older_percent'].isnull()]
nan_aged65
# Out:
#                         location       date  new_cases  new_deaths  \
# 2468                     Bermuda 2020-03-20          2           0
# 2469                     Bermuda 2020-03-21          0           0
# 2470                     Bermuda 2020-03-22          0           0
# 2471                     Bermuda 2020-03-23          4           0
# 2472                     Bermuda 2020-03-24          0           0
# ...                          ...        ...        ...         ...
# 18751  Sint Maarten (Dutch part) 2020-06-06          0           0
# 18752  Sint Maarten (Dutch part) 2020-06-07          0           0
# 18753  Sint Maarten (Dutch part) 2020-06-08          0           0
# 18754  Sint Maarten (Dutch part) 2020-06-09          0           0
# 18755  Sint Maarten (Dutch part) 2020-06-10          0           0
#
#        population  aged_65_older_percent  gdp_per_capita  \
# 2468        62273                    NaN       50669.315
# ...

# %%
df.dropna(subset=['aged_65_older_percent'], inplace = True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 20062 entries, 0 to 23017
# Data columns (total 8 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   location                    20062 non-null  object
#  1   date                        20062 non-null  datetime64[ns]
#  2   new_cases                   20062 non-null  int64
#  3   new_deaths                  20062 non-null  int64
#  4   population                  20062 non-null  int64
#  5   aged_65_older_percent       20062 non-null  float64
#  6   gdp_per_capita              20062 non-null  float64
#  7   hospital_beds_per_thousand  18328 non-null  float64
# dtypes: datetime64[ns](1), float64(3), int64(3), object(1)
# memory usage: 1.4+ MB

# %%
df['hospital_beds_per_thousand'].isnull().sum()
# Out:
# 1734

# %%
nan_beds = df[df['hospital_beds_per_thousand'].isnull()]
nan_beds
# Out:
#           location       date  new_cases  new_deaths  population  \
# 494         Angola 2020-03-22          2           0    32866268
# 495         Angola 2020-03-23          0           0    32866268
# 496         Angola 2020-03-24          0           0    32866268
# 497         Angola 2020-03-25          0           0    32866268
# 498         Angola 2020-03-26          0           0    32866268
# ...            ...        ...        ...         ...         ...
# 19383  South Sudan 2020-06-06          0           0    11193729
# 19384  South Sudan 2020-06-07          0           0    11193729
# 19385  South Sudan 2020-06-08          0           0    11193729
# 19386  South Sudan 2020-06-09        287           5    11193729
# 19387  South Sudan 2020-06-10          0           0    11193729
#
#        aged_65_older_percent  gdp_per_capita  hospital_beds_per_thousand
# 494                    2.405        5819.495                         NaN
# ...

# %%
df.describe()
# Out:
#            new_cases    new_deaths    population  aged_65_older_percent  \
# count   20062.000000  20062.000000  2.006200e+04           20062.000000
# mean      718.266225     40.971090  1.185816e+08               9.714828
# std      5912.396551    354.720017  7.182728e+08               6.475695
# min     -2461.000000  -1918.000000  9.792800e+04               1.144000
# 25%         0.000000      0.000000  4.105268e+06               3.810000
# 50%         5.000000      0.000000  1.042306e+07               7.151000
# 75%        81.000000      2.000000  4.022250e+07              15.168000
# max    133510.000000  10520.000000  7.794799e+09              27.049000
#
#        gdp_per_capita  hospital_beds_per_thousand
# count    20062.000000                20062.000000
# mean     22252.646959                    3.080595
# std      21104.469134                    2.351259
# min        661.240000                    0.100000
# 25%       6253.104000                    1.400000
# ...

# %%
median_hospital_beds_per_thousand = df['hospital_beds_per_thousand'].median()
df['hospital_beds_per_thousand'].fillna(median_hospital_beds_per_thousand, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 20062 entries, 0 to 23017
# Data columns (total 8 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   location                    20062 non-null  object
#  1   date                        20062 non-null  datetime64[ns]
#  2   new_cases                   20062 non-null  int64
#  3   new_deaths                  20062 non-null  int64
#  4   population                  20062 non-null  int64
#  5   aged_65_older_percent       20062 non-null  float64
#  6   gdp_per_capita              20062 non-null  float64
#  7   hospital_beds_per_thousand  20062 non-null  float64
# dtypes: datetime64[ns](1), float64(3), int64(3), object(1)
# memory usage: 1.4+ MB

# %%
df.head()
# Out:
#       location       date  new_cases  new_deaths  population  \
# 0  Afghanistan 2019-12-31          0           0    38928341
# 1  Afghanistan 2020-01-01          0           0    38928341
# 2  Afghanistan 2020-01-02          0           0    38928341
# 3  Afghanistan 2020-01-03          0           0    38928341
# 4  Afghanistan 2020-01-04          0           0    38928341
#
#    aged_65_older_percent  gdp_per_capita  hospital_beds_per_thousand
# 0                  2.581        1803.987                         0.5
# 1                  2.581        1803.987                         0.5
# 2                  2.581        1803.987                         0.5
# 3                  2.581        1803.987                         0.5
# 4                  2.581        1803.987                         0.5

# %%
value_counts = df['date'].value_counts()
value_counts
# Out:
# 2020-05-17    177
# 2020-05-20    177
# 2020-05-27    177
# 2020-05-28    177
# 2020-05-29    177
#              ...
# 2020-01-19     64
# 2020-01-18     64
# 2020-03-04     60
# 2020-03-05     60
# 2020-03-03     53
# Name: date, Length: 163, dtype: int64

# %% [markdown]
# # Univariate Analysis on Column - Location

# %%
sns.countplot(df['new_cases'])
# Out:
# <Axes: ylabel='count'>

# %%
df['population'].value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='population'>

# %%
plt.hist(df['location'])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-76-05ffd737642d> in <cell line: 1>()
# ----> 1 plt.hist(df['location']).head(5)
#
# AttributeError: 'tuple' object has no attribute 'head'

# %%
import pandas as pd

# Create a sample DataFrame
data = {'A': [1, 2, 3, 4],
        'B': ['X', 'Y', 'Z', 'W']}
df = pd.DataFrame(data)

# Set 'B' column as the index
df.set_index('B', inplace=True)

# Reset the index
df.reset_index(drop=False, inplace=True)

# Display the modified DataFrame
print(df)
# Out:
#    B  A
# 0  X  1
# 1  Y  2
# 2  Z  3
# 3  W  4
